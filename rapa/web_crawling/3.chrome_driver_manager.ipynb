# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time
options = webdriver.ChromeOptions()
options.add_argument("window-size=1000,1000")
options.add_argument("no-sandbox")

chrome = webdriver.Chrome(ChromeDriverManager().install(), options=options)
chrome.get("http://naver.com")
chrome.get("http://shopping.naver.com")
chrome.back()
time.sleep(2)
chrome.forward()
time.sleep(2)
chrome.close()
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 95.0.4638
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - There is no [linux64] chromedriver for browser 95.0.4638 in cache
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - Trying to download new driver from https://chromedriver.storage.googleapis.com/95.0.4638.54/chromedriver_linux64.zip
# [WDM] - Driver has been saved in cache [/home/hans/.wdm/drivers/chromedriver/linux64/95.0.4638.54]
# /tmp/ipykernel_146797/3435964174.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   chrome = webdriver.Chrome(ChromeDriverManager().install(), options=options)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time
from selenium.webdriver.common.by import By
chrome = webdriver.Chrome(ChromeDriverManager().install())
chrome.get('http://daum.net')
elem = chrome.find_element(By.CLASS_NAME, "link_login")
elem.click()
chrome.find_element_by_class_name("btn_g").click()
chrome.back()
time.sleep(2)
chrome.forward()
time.sleep(2)

chrome.back()
time.sleep(2)
elem = chrome.find_element_by_name("q")
elem.send_keys("사과")
elem.send_keys("바나나")
chrome.find_element_by_id("q").clear()
elem.send_keys("사과")
elem.send_keys(Keys.ENTER)
items = chrome.find_elements_by_class_name("thumb_img")
for item in items:
    print(item.get_attribute("src"))
chrome.close()
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 95.0.4638
# [WDM] - Get LATEST driver version for 95.0.4638
# [WDM] - Driver [/home/hans/.wdm/drivers/chromedriver/linux64/95.0.4638.54/chromedriver] found in cache
# /tmp/ipykernel_146797/1500357025.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   chrome = webdriver.Chrome(ChromeDriverManager().install())
# /tmp/ipykernel_146797/1500357025.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   chrome.find_element_by_class_name("btn_g").click()
# /tmp/ipykernel_146797/1500357025.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = chrome.find_element_by_name("q")
# /tmp/ipykernel_146797/1500357025.py:21: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   chrome.find_element_by_id("q").clear()
# /tmp/ipykernel_146797/1500357025.py:24: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   items = chrome.find_elements_by_class_name("thumb_img")
# https://img.nate.com/kwshop/ad_img/nice/2021/05/E0/N20210521-001440-1.jpg?2105311627
# https://img.nate.com/kwshop/ad_img/nice/2016/12/3A/N20161209-148730-1.gif?1612090939
# https://img.nate.com/kwshop/ad_img/nice/2016/06/9A/N20160624-000154-1.gif?1606241408
# https://img.nate.com/kwshop/ad_img/nice/2020/06/A1/N20200617-024929-1.gif?2006171512
# https://search2.daumcdn.net/thumb/R80x80/?fname=http%3A//shop2.daumcdn.net/shophow/p/P13110714313.jpg%3Fut%3D20211100000000
# https://search2.daumcdn.net/thumb/R80x80/?fname=http%3A//shop1.daumcdn.net/shophow/p/I14548393031.jpg%3Fut%3D20211100000000
# https://search1.daumcdn.net/thumb/R80x80/?fname=http%3A//shop1.daumcdn.net/shophow/p/V3981346410.jpg%3Fut%3D20211100000000
# https://search1.daumcdn.net/thumb/R80x80/?fname=http%3A//shop2.daumcdn.net/shophow/p/B2409986139.jpg%3Fut%3D20211100000000
# https://search2.daumcdn.net/thumb/R80x80/?fname=http%3A//shop2.daumcdn.net/shophow/p/M14718790917.jpg%3Fut%3D20211100000000
